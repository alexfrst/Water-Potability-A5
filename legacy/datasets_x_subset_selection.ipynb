# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import itertools
import time
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('drinking_water_potability.csv')
df["Missing"] = df.isna().sum(axis=1)
dimensions = ["ph",
              "Hardness",
              "Solids",
              "Chloramines",
              "Sulfate",
              "Conductivity",
              "Organic_carbon",
              "Trihalomethanes",
              "Turbidity"]

# %% [markdown]
# ### Création datasets

# %%
#from sklearn.preprocessing import Imputer
from sklearn.impute import SimpleImputer

# %%
# 1 : Suppression de toutes les lignes avec 2 ou 3 valeurs manquantes et imputation pour les lignes avec 1 valeur manquante
df_missing_1 = df.dropna(thresh=10)

# %%
# 1.1 : Mean-imputer
imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
imp_mean.fit(df_missing_1)
df_missing_11=pd.DataFrame(imp_mean.transform(df_missing_1))

#df_missing_11.head()

# %%
# 1.2 : Median-imputer
imp_median = SimpleImputer(missing_values=np.nan, strategy='median')
imp_median.fit(df_missing_1)
df_missing_12=pd.DataFrame(imp_median.transform(df_missing_1))

# %%
# 2 : Suppression des lignes avec 3 valeurs manquantes et imputation pour les autres
df_missing_2 = df.dropna(thresh=9)

# %%
# 2.1 : Mean
imp_mean.fit(df_missing_2)
df_missing_21=pd.DataFrame(imp_mean.transform(df_missing_2))

# %%
# 2.2 : Median
imp_median.fit(df_missing_2)
df_missing_22=pd.DataFrame(imp_median.transform(df_missing_2))

# %%
#Dictionnaire qui contient les dataframes d'intérêt
all_df_missing={"df_missing_11" : df_missing_11,"df_missing_12" : df_missing_12, 
                  "df_missing_21" : df_missing_21, "df_missing_22" : df_missing_22}

for dataframe in all_df_missing.values() :
   #on redonne d'abord les noms des colonnes qui ont disparu
   dataframe.columns=['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
       'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability',
       'Missing']

# %%
for dataframe in all_df_missing.values() :   
   dataframe.drop('Missing', axis=1, inplace=True)
    #fig = px.scatter(y=dataframe.loc[:,"ph"])
   dataframe.columns
    #fig.show()

# %%
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer

df_missing_3 = df.dropna(thresh=10)
imp_iter = IterativeImputer(random_state=0)
df_missing_3 = pd.DataFrame(imp_iter.fit_transform(df_missing_3))
df_missing_3.columns = ['ph', 'Hardness', 'Solids', 'Chloramines', 'Sulfate', 'Conductivity',
       'Organic_carbon', 'Trihalomethanes', 'Turbidity', 'Potability',
       'Missing']
df_missing_3.drop('Missing', axis=1, inplace=True)
df_missing_1.drop('Missing', axis=1, inplace=True)
df_missing_2.drop('Missing', axis=1, inplace=True)
all_df_missing["df_missing_3"] = df_missing_3
# Out:
# C:\Users\theoc\anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_missing_0 = df.dropna().drop(['Missing'],axis=1)
all_df_missing["df_missing_0"] = df_missing_0

# %% [markdown]
# # Iterative Imputer
#
# ### Nous allons ici utiliser une imputation multivariable sur les données ayant max 2 valeurs manquantes.

# %%
from sklearn.experimental import enable_iterative_imputer  # noqa
from sklearn.impute import IterativeImputer

df_4 = df.dropna(thresh=10)
imp_iter = IterativeImputer(random_state=0)
df_4 = pd.DataFrame(imp_iter.fit_transform(df_4))

# %% [markdown]
# ### Forward subset selection

# %% [markdown]
# #### Définition modeles

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import f1_score

# Build RF classifier to use in feature selection
SVM_rbf = SVC(C=10, gamma=0.1)
clf = RandomForestClassifier()

def mean_norm(df_input):
    return df_input.apply(lambda x: (x-x.mean())/ x.std(), axis=0)

# %%
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.model_selection import train_test_split

def forward_selection(model,X,y):

        if scale:
                X_scaled = mean_norm(X)
                X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.5, random_state=42)
        else:
                X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=42)

        # Build step forward feature selection
        sfs1 = sfs(model,
                k_features=9,
                forward=True,
                floating=False,
                verbose=2,
                scoring='f1',
                cv=5,
                n_jobs=-1)

         # Perform SFFS on train set
        feature_names = X.columns
        sfs1 = sfs1.fit(X_train, y_train,custom_feature_names=feature_names)

        return sfs1.get_metric_dict()

# %%
def impute_sfs_one_dataset(model, dataset):

    X = dataset.drop(['Potability'],axis=1)
    y = dataset.Potability
    
    results_dict = forward_selection(model, X, y)
    results_df = pd.DataFrame.from_dict(results_dict).transpose()
    results_df.sort_values('avg_score', inplace=True, ascending=False)
    
    return results_df

# %%
def impute_sfs_all_datasets(model, datasets, scale = False):

    best_results = pd.DataFrame(columns = ['Dataset_name', 'Feature_names', 'f1_score'])
    keys = list(all_df_missing.keys())
    i = 0

    for dataset in datasets.values():
        results_df = impute_sfs_one_dataset(model, dataset)
        results_df.reset_index(drop=True, inplace=True)
        carac_dataset = [keys[i], results_df.loc[0, 'feature_names'], results_df.loc[0, 'avg_score']]
        best_results.loc[i] = carac_dataset
        i += 1
        
    best_results.sort_values('f1_score', inplace=True, ascending=False)
    
    return best_results

# %%
best_results_clf = impute_sfs_all_datasets(clf, all_df_missing)
best_results_clf
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:   14.3s remaining:   17.9s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:   16.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:   16.3s finished
#
# [2021-11-04 02:53:04] Features: 1/9 -- score: 0.443660706986964[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    3.3s remaining:    5.5s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    4.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    4.4s finished
#
# [2021-11-04 02:53:09] Features: 2/9 -- score: 0.4304008232139417[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    4.0s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    4.3s finished
#
# [2021-11-04 02:53:13] Features: 3/9 -- score: 0.4619919880443356[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    4.3s remaining:    4.3s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    4.4s finished
#
# [2021-11-04 02:53:18] Features: 4/9 -- score: 0.49516525839181247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    3.8s remaining:    5.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    4.0s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    4.0s finished
#
# [2021-11-04 02:53:22] Features: 5/9 -- score: 0.491034419698597[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    3.4s finished
#
# [2021-11-04 02:53:25] Features: 6/9 -- score: 0.5157559079970017[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.9s finished
#
# [2021-11-04 02:53:28] Features: 7/9 -- score: 0.4826992090362269[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    1.8s finished
#
# [2021-11-04 02:53:30] Features: 8/9 -- score: 0.47212617427982567[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.9s finished
#
# [2021-11-04 02:53:32] Features: 9/9 -- score: 0.4637971973565576[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:    4.0s remaining:    5.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    5.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    5.5s finished
#
# [2021-11-04 02:53:38] Features: 1/9 -- score: 0.443660706986964[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    2.7s remaining:    4.5s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    3.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    3.8s finished
#
# [2021-11-04 02:53:42] Features: 2/9 -- score: 0.43459630359214285[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    2

# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    4.0s finished
#
# [2021-11-04 02:55:28] Features: 4/9 -- score: 0.5005469972810792[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    3.1s remaining:    4.7s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    3.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    3.2s finished
#
# [2021-11-04 02:55:31] Features: 5/9 -- score: 0.5116397554617637[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    2.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    2.9s finished
#
# [2021-11-04 02:55:34] Features: 6/9 -- score: 0.509665663445934[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.4s finished
#
# [2021-11-04 02:55:36] Features: 7/9 -- score: 0.4859020212532938[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.0s finished
#
# [2021-11-04 02:55:39] Features: 8/9 -- score: 0.4661103150937794[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    3.0s finished
#
# [2021-11-04 02:55:42] Features: 9/9 -- score: 0.4657830565153511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:    3.4s remaining:    4.2s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    4.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    4.5s finished
#
# [2021-11-04 02:55:46] Features: 1/9 -- score: 0.4407902518598033[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    3.2s remaining:    5.4s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    3.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    3.7s finished
#
# [2021-11-04 02:55:50] Features: 2/9 -- score: 0.42435529627087626[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    2.7s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    2.8s finished
#
# [2021-11-04 02:55:53] Features: 3/9 -- score: 0.4795162471421464[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    2.8s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    2.8s finished
#
# [2021-11-04 02:55:56] Features: 4/9 -- score: 0.5055895994211357[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    2.5s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.6s finished
#
# [2021-11-04 02:55:59] Features: 5/9 -- score: 0.5197061565886949[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    2.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    2.8s finished
#
# [2021-11-04 02:56:02] Features: 6/9 -- score: 0.5017415494546884[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    3.2s finished
#
# [2021-11-04 02:56:05] Features: 7/9 -- score: 0.46941538901803304[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.8s finished
#
# [2021-11-04 02:56:08] Features: 8/9 -- score: 0.420256026644329[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    2.5s finished
#
# [2021-11-04 02:56:10] Features: 9/9 -- score: 0.4283947780852597
#     Dataset_name                                      Feature_names  f1_score
# 5   df_missing_0       (ph, Hardness, Solids, Chloramines, Sulfate)  0.519706
# 0  df_missing_11  (ph, Hardness, Solids, Chloramines, Sulfate, C...  0.515756
# 4   df_missing_3       (ph, Hardness, Solids, Chloramines, Sulfate)  0.511640
# 1  df_missing_12  (ph, Hardness, Solids, Chloramines, Sulfate, C...  0.507628
# 3  df_missing_22   (ph, Hardness, Solids, Sulfate, Trihalomethanes)  0.490221
# 2  df_missing_21  (ph, Hardness, Solids, Chloramines, Sulfate, T...  0.479521

# %%
best_results_svm = impute_sfs_all_datasets(SVM_rbf, all_df_missing, scale=True)
best_results_svm
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:    2.9s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    4.5s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    4.5s finished
#
# [2021-11-04 03:09:49] Features: 1/9 -- score: 0.3392013075536392[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    3.1s remaining:    5.3s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    3.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    3.8s finished
#
# [2021-11-04 03:09:53] Features: 2/9 -- score: 0.4250796134975275[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    2.3s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    3.3s finished
#
# [2021-11-04 03:09:56] Features: 3/9 -- score: 0.4279501712133758[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    2.1s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    2.7s finished
#
# [2021-11-04 03:09:59] Features: 4/9 -- score: 0.41321865699935145[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    1.8s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.6s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.6s finished
#
# [2021-11-04 03:10:02] Features: 5/9 -- score: 0.39229030208653437[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    3.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    3.2s finished
#
# [2021-11-04 03:10:05] Features: 6/9 -- score: 0.33586248805427277[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2
Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.6s finished
#
# [2021-11-04 03:11:24] Features: 9/9 -- score: 0.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:    2.7s remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    3.4s finished
#
# [2021-11-04 03:11:28] Features: 1/9 -- score: 0.33078532205557365[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    2.1s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    2.4s finished
#
# [2021-11-04 03:11:30] Features: 2/9 -- score: 0.41824116296592384[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    2.1s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    2.9s finished
#
# [2021-11-04 03:11:33] Features: 3/9 -- score: 0.4373585330264632[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    1.9s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    2.9s finished
#
# [2021-11-04 03:11:36] Features: 4/9 -- score: 0.452179064634605[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    1.6s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.4s finished
#
# [2021-11-04 03:11:39] Features: 5/9 -- score: 0.4450980635800885[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    2.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    2.2s finished
#
# [2021-11-04 03:11:41] Features: 6/9 -- score: 0.30762654588738475[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    2.5s finished
#
# [2021-11-04 03:11:44] Features: 7/9 -- score: 0.052018516367565826[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    2.2s finished
#
# [2021-11-04 03:11:46] Features: 8/9 -- score: 0.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    1.7s finished
#
# [2021-11-04 03:11:48] Features: 9/9 -- score: 0.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   9 | elapsed:    1.5s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    1.8s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   9 out of   9 | elapsed:    1.8s finished
#
# [2021-11-04 03:11:50] Features: 1/9 -- score: 0.3684631736938999[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   8 | elapsed:    1.0s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.2s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   8 out of   8 | elapsed:    1.2s finished
#
# [2021-11-04 03:11:51] Features: 2/9 -- score: 0.41486697889575586[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   7 | elapsed:    1.1s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done   7 out of   7 | elapsed:    1.3s finished
#
# [2021-11-04 03:11:53] Features: 3/9 -- score: 0.43979532213848926[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   6 | elapsed:    0.9s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done   6 out of   6 | elapsed:    1.1s finished
#
# [2021-11-04 03:11:54] Features: 4/9 -- score: 0.4559084833713342[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   5 | elapsed:    0.6s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.7s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.7s finished
#
# [2021-11-04 03:11:55] Features: 5/9 -- score: 0.4538290954104781[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.9s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done   4 out of   4 | elapsed:    0.9s finished
#
# [2021-11-04 03:11:56] Features: 6/9 -- score: 0.32701280145465084[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 out of   3 | elapsed:    0.7s finished
#
# [2021-11-04 03:11:56] Features: 7/9 -- score: 0.046073049935393975[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of   2 | elapsed:    0.7s finished
#
# [2021-11-04 03:11:57] Features: 8/9 -- score: 0.0[Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    0.5s finished
#
# [2021-11-04 03:11:58] Features: 9/9 -- score: 0.0
#     Dataset_name                                      Feature_names  f1_score
# 5   df_missing_0         (ph, Chloramines, Sulfate, Organic_carbon)  0.455908
# 4   df_missing_3              (ph, Chloramines, Sulfate, Turbidity)  0.452179
# 1  df_missing_12  (ph, Chloramines, Sulfate, Organic_carbon, Tur...  0.451742
# 0  df_missing_11                     (ph, Sulfate, Trihalomethanes)  0.427950
# 2  df_missing_21        (ph, Chloramines, Sulfate, Trihalomethanes)  0.423370
# 3  df_missing_22        (ph, Chloramines, Sulfate, Trihalomethanes)  0.422363
